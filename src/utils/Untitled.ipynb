# %%
from layers_new import GumbelSoftmax

import tensorflow as tf
from tensorflow.keras.layers import Input
from tensorflow.keras import Sequential

# %%
model = Sequential()

model.add(GumbelSoftmax())

# %%
model.build(input_shape=[512,21])

# %%
model.save("test.h5")

# %%
new_model = tf.keras.models.load_model('/mnt/vault1/ThermalGAN/data/processed/EE_22_10_10/Experiment_non_redundant_v3_psychro/results/experiments/20221029-160002train_from_scratch.yaml/weights/epoch_0/generator_G.h5', custom_objects={'GumbelSoftmax': GumbelSoftmax})
# Out:
# WARNING:root:The given value for groups will be overwritten.
# WARNING:tensorflow:AutoGraph could not transform <bound method GroupNormalization.call of <tensorflow_addons.layers.normalizations.InstanceNormalization object at 0x7f09ec799fd0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <bound method GroupNormalization.call of <tensorflow_addons.layers.normalizations.InstanceNormalization object at 0x7f09ec799fd0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# ...

# %%
new_model.optimizer.lr
# Out:
# <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
